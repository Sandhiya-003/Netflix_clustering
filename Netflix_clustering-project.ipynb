# %% [markdown]
# # **Project Name**    - **Netflix Clustering Project**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# This project focuses on performing exploratory data analysis (EDA) and clustering on a dataset of Netflix movies and TV shows to uncover meaningful patterns and group similar content. With the rapid growth of streaming platforms, understanding content distribution and user preferences has become essential for improving recommendation systems and enhancing user experience. The primary objective of this project is to analyze Netflix’s content library and identify natural clusters within the data using unsupervised learning techniques.
#
# The dataset used in this project contains information about movies and TV shows available on Netflix, including attributes such as type (Movie or TV Show), title, director, cast, country, release year, rating, duration, and genre. Initially, the dataset was explored to understand its structure, data types, and the presence of missing values. Data cleaning and preprocessing steps were carried out to improve data quality. Missing values in columns such as director, cast, and country were handled by replacing them with “Unknown,” while missing values in the rating column were filled using the most frequent value. Duplicate records were also removed to ensure accuracy.
#
# Exploratory Data Analysis (EDA) was conducted to gain insights into the dataset. Various visualizations were created to analyze the distribution of content across different dimensions. It was observed that movies dominate the platform compared to TV shows, indicating a higher volume of movie content. Countries like the United States and India were identified as major contributors to the dataset. Genre analysis revealed that Drama and Comedy are among the most popular categories. Additionally, a noticeable increase in content production was observed after 2015, reflecting the rapid expansion of streaming services.
#
# To prepare the data for clustering, feature engineering techniques were applied. Since machine learning models require numerical input, categorical variables such as type, rating, and genre were converted into numerical form using Label Encoding. A new feature representing the primary genre was created by extracting it from the listed_in column. The selected features were then scaled using StandardScaler to ensure that all variables contributed equally to the clustering process.
#
# The clustering results revealed clear patterns in the data. Each cluster represented a group of similar content, such as movies, TV shows, or specific genre-based categories. These groupings can be useful for improving recommendation systems by suggesting similar content to users based on their viewing preferences.
#
# In conclusion, this project demonstrates how data analysis and clustering techniques can be used to organize and understand large content datasets. The insights gained can help improve content recommendations, enhance user experience, and support better business decisions for streaming platforms like Netflix.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The objective of this project is to group Netflix movies and TV shows into meaningful clusters based on their features, in order to identify similar content and support better content recommendations.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective of this project is to analyze and cluster Netflix movies and TV shows based on their features in order to identify similar content groups. This helps in improving recommendation systems, enabling personalized content suggestions, and enhancing user engagement. Additionally, the insights derived from clustering can support data-driven decisions in content creation, acquisition, and platform strategy.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Data Handling
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Clustering Model
from sklearn.cluster import KMeans

# Evaluation
from sklearn.metrics import silhouette_score

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import files

uploaded = files.upload()

# %%
import pandas as pd

df = pd.read_csv('netflix_titles.csv')
df.head()

# %% [markdown]
# ### Dataset First View

# %%
df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")

# %% [markdown]
# ### Dataset Information

# %%
df.describe()

# %% [markdown]
# #### Duplicate Values

# %%
print(f"Duplicate rows: {df.duplicated().sum()}")

# %% [markdown]
# #### Missing Values/Null Values

# %%
print(df.isnull().sum())

# %%
sns.heatmap(df.isnull(), cbar=False)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains information about Netflix movies and TV shows, including details such as type (movie or TV show), title, director, cast, country, release year, rating, duration, and genre.
#
# It includes both categorical and numerical features, with some missing values present in columns like director, cast, and country.
#
# The dataset provides a comprehensive view of Netflix content, which can be used to analyze patterns and group similar content using clustering techniques.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
df.columns

# %%
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# - **`show_id`**: Unique ID for each show (movie or TV show).
# - **`type`**: Type of content, either 'Movie' or 'TV Show'.
# - **`title`**: Title of the movie or TV show.
# - **`director`**: Director(s) of the content. Missing values indicate no director information available.
# - **`cast`**: Main actors/actresses in the content. Missing values indicate no cast information available.
# - **`country`**: Country(s) where the content was produced. Missing values indicate no country information available.
# - **`date_added`**: Date when the content was added to Netflix.
# - **`release_year`**: Year the content was originally released.
# - **`rating`**: TV rating of the content (e.g., 'TV-MA', 'R', 'PG-13').
# - **`duration`**: Duration of the content (e.g., '93 min' for movies, '4 Seasons' for TV shows).
# - **`listed_in`**: Genres or categories the content belongs to.
# - **`description`**: A brief summary or synopsis of the content.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
for col in df.columns:
    print(f"Column: {col}")
    print(df[col].nunique())
    print(df[col].unique()[:10])  # show first 10 unique values
    print("-"*50)

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# Handle missing values
df['director'].fillna('Unknown', inplace=True)
df['cast'].fillna('Unknown', inplace=True)
df['country'].fillna('Unknown', inplace=True)
df['rating'].fillna(df['rating'].mode()[0], inplace=True)

# Convert date_added to datetime
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# Extract year and month from date_added
df['year_added'] = df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month

# Extract main genre (first genre)
df['main_genre'] = df['listed_in'].apply(lambda x: x.split(',')[0])

# Clean duration (optional improvement)
df['duration'] = df['duration'].astype(str)

df.head()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# In this dataset, several preprocessing steps were performed. Duplicate records were removed to ensure data quality. Missing values in important columns such as director, cast, and country were handled by replacing them with "Unknown", while missing values in the rating column were filled using the most frequent value.
#
# The date_added column was converted into datetime format, and new features such as year_added and month_added were extracted to enable time-based analysis.
#
# Additionally, the listed_in column containing multiple genres was simplified by extracting the primary genre into a new column called main_genre.
#
# These transformations made the dataset cleaner and more suitable for analysis and clustering, improving the overall quality of insights derived from the data.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
df['type'].value_counts().plot(kind='bar')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **To understand distribution of content types.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Movies are more than TV Shows.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Netflix can invest more in TV shows to balance content and attract binge users.**

# %% [markdown]
# #### Chart - 2

# %%
df['country'].value_counts().head(10).plot(kind='bar')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **To identify top content-producing countries.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **USA and India dominates**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Helps Netflix focus on high-performing regions**

# %% [markdown]
# #### Chart - 3

# %%
df['release_year'].value_counts().sort_index().plot()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **To identify top content-producing countries.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Content increased after 2015**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Indicates growing demand for streaming content.**

# %% [markdown]
# #### Chart - 4

# %%
df['rating'].value_counts().plot(kind='bar')
plt.title("Rating Distribution")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **To understand targeting audience**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **TV-MA and TV-14 dominate.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Focus on adult and teen content**

# %% [markdown]
# #### Chart - 5

# %%
df['duration'].value_counts().head(10).plot(kind='bar')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **To analyze movie length**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Most movies arein standard length**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Optimize content duration**

# %% [markdown]
# #### Chart - 6

# %%
df['main_genre'].value_counts().head(10).plot(kind='bar')
plt.title("Top Genres")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **To identify popular genres**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Drama and comedy shows dominate**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Invest more in popular genres**

# %%
df['duration'].value_counts().head(10).plot(kind='bar')

# %% [markdown]
# #### Chart - 7

# %%
sns.countplot(x='release_year', hue='type', data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **To compare trends**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Movies dominate across years**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Opportunity to grow TV content**

# %% [markdown]
# #### Chart - 8

# %%
df['director'].value_counts().head(10).plot(kind='bar')
plt.title("Top Directors")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **To identify frequent contributors**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Few director dominate**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Helps partnerships**

# %% [markdown]
# #### Chart - 9

# %%
pd.crosstab(df['country'], df['type']).head(10).plot(kind='bar')
plt.show()

# %% [markdown]
# 1.Why did you pick the specific chart?

# %% [markdown]
# **To compare content types by country**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Some countries focus more on movies**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Helps regional strategy**

# %% [markdown]
# #### Chart - 10

# %%
df['main_genre'] = df['listed_in'].apply(lambda x: x.split(',')[0])
sns.countplot(y='main_genre', hue='type', data=df, order=df['main_genre'].value_counts().index[:10])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **To analyze how genre relates to audience rating**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Certain genres are more adult oriented**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Helps target specific audience group**

# %% [markdown]
# #### Chart - 11

# %%
pd.crosstab(df['main_genre'], df['rating']).plot(kind='bar', stacked=True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **To analyze genre vs audience**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Certain genre target specific age groups**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Improves target recommendations**

# %% [markdown]
# #### Chart - 12

# %%
df['year_added'].value_counts().sort_index().plot()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **To see netflix growth**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Content addition increased over time**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Shows expansion strategy**

# %% [markdown]
# #### Chart - 13

# %%
df['cluster'].value_counts().plot(kind='bar')
plt.title("Cluster Distribution")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **To understand the clustering result**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Data is grouped into clusters**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Will help in recommendation systems

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['type_enc'] = le.fit_transform(df['type'])
df['rating_enc'] = le.fit_transform(df['rating'])
df['genre_enc'] = le.fit_transform(df['main_genre'])

import seaborn as sns
sns.heatmap(df[['type_enc','rating_enc','genre_enc']].corr(), annot=True)

# %% [markdown]
# ### Clustering for Recommendation Systems

# %%
# Select features for clustering
# Using numerical features and previously encoded categorical features
features_for_clustering = df[['release_year', 'year_added', 'type_enc', 'rating_enc', 'genre_enc']].copy()

# Handle potential NaN values from date_added conversion (year_added)
# Filling with median as it's less sensitive to outliers than mean
features_for_clustering['year_added'].fillna(features_for_clustering['year_added'].median(), inplace=True)

# Standardize the features to ensure all features contribute equally to the distance calculation
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features_for_clustering)

# Determine the optimal number of clusters using the Elbow Method
# This part helps to visualize and choose a suitable 'k' for KMeans
wcss = [] # Within-cluster sum of squares
for i in range(1, 11):
    kmeans_model = KMeans(n_clusters=i, init='k-means++', random_state=42, n_init=10)
    kmeans_model.fit(scaled_features)
    wcss.append(kmeans_model.inertia_)

# Plot the Elbow Method to find the optimal number of clusters
plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), wcss, marker='o', linestyle='--')
plt.title('Elbow Method to Determine Optimal K')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('WCSS (Within-Cluster Sum of Squares)')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### **Insight from Elbow Method:**
# Based on the elbow plot, choose an appropriate number of clusters where the decrease in WCSS begins to level off. For this dataset, let's assume 5 clusters are optimal for demonstration, but this can be adjusted based on the plot.

# %%
# Apply KMeans clustering with the chosen number of clusters
# Here, we'll use 5 clusters as an example from the elbow method
optimal_clusters = 5 # This can be adjusted based on the elbow plot observation
kmeans = KMeans(n_clusters=optimal_clusters, init='k-means++', random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(scaled_features)

print(f"Clustering performed with {optimal_clusters} clusters. A new 'cluster' column has been added to the DataFrame.")

df.head()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **To find relationships**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Negative correlation exists**

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
sns.pairplot(df[['type_enc','rating_enc','genre_enc']])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **To visualize relationships**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Patterns and clusters are visible**

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To achieve the business objective of improving content organization and user engagement, it is recommended that Netflix leverages clustering insights to group similar movies and TV shows.
#
# By identifying patterns in content such as genre, rating, and type, Netflix can enhance its recommendation system to provide more personalized suggestions to users. This will improve user satisfaction and increase watch time.
#
# Additionally, the platform can focus on producing or acquiring more content in high-demand clusters such as popular genres (e.g., drama and comedy) and regions with higher audience engagement.
#
# Netflix can also use clustering results to optimize content categorization, making it easier for users to discover content based on their preferences.
#
# Overall, data-driven clustering helps in better decision-making, targeted content strategy, and improved customer experience.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In this project, we performed exploratory data analysis and clustering on the Netflix Movies and TV Shows dataset to identify meaningful patterns and group similar content.
#
# Initially, the dataset was cleaned by handling missing values and duplicates. Various visualizations were created to understand the distribution of content based on type, genre, country, and release year.
#
# After preprocessing the data and converting categorical features into numerical format, KMeans clustering was applied to group similar content into distinct clusters. The optimal number of clusters was determined using the Elbow Method.
#
# The clustering results revealed clear patterns in content distribution, such as differences between movies and TV shows, genre-based groupings, and audience targeting based on ratings.
#
# These insights can help Netflix improve its recommendation system, enhance user experience, and make informed business decisions regarding content production and acquisition.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
